# %%
import replicator

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
payoffs = np.array([[2.85651163, 2.85046332, 2.89      , 1.29      ],
                   [2.85046332, 2.84446154, 3.042     , 1.29      ],
                   [2.89      , 2.642     , 2.89      , 0.41      ],
                   [1.29      , 1.29      , 4.41      , 1.29      ]])

# %%
vert_labels = ["A", "B", "C", "D"]

# %%
replicator.plot3D(payoffs, vert_labels);
